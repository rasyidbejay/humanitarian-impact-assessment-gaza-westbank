# %% [markdown]
# ## Licensing Note
#
# This project uses humanitarian datasets from [Tech for Palestine Data Hub](https://data.techforpalestine.org), licensed under [CC BY 4.0](https://creativecommons.org/licenses/by/4.0/). Proper attribution has been maintained.

# %%
import pandas as pd
import numpy as np
import json

casualties = pd.read_csv('/kaggle/input/gaza-and-west-bank-humanitarian-data-202324/casualties_daily.csv')
west_bank = pd.read_csv('/kaggle/input/gaza-and-west-bank-humanitarian-data-202324/west_bank_daily.csv')
press_killed = pd.read_csv('/kaggle/input/gaza-and-west-bank-humanitarian-data-202324/press_killed_in_gaza.csv')

with open('/kaggle/input/gaza-and-west-bank-humanitarian-data-202324/infrastructure-damaged.json') as f:
    infra_json = json.load(f)

# %%
casualties.head()
west_bank.head()
press_killed.head()
infra_json
# Out:
# [{'report_date': '2023-10-07',
#   'civic_buildings': {'ext_destroyed': 5},
#   'educational_buildings': {'ext_destroyed': 1, 'ext_damaged': 15},
#   'places_of_worship': {'ext_mosques_destroyed': 2,
#    'ext_mosques_damaged': 4,
#    'ext_churches_destroyed': 0},
#   'residential': {'ext_destroyed': 80}},
#  {'report_date': '2023-10-08',
#   'civic_buildings': {'ext_destroyed': 11},
#   'educational_buildings': {'ext_destroyed': 1, 'ext_damaged': 30},
#   'places_of_worship': {'ext_mosques_destroyed': 4,
#    'ext_mosques_damaged': 8,
#    'ext_churches_destroyed': 0},
#   'residential': {'destroyed': 159, 'ext_destroyed': 159}},
#  {'report_date': '2023-10-09',
#   'civic_buildings': {'ext_destroyed': 16},
#   'educational_buildings': {'ext_destroyed': 2, 'ext_damaged': 45},
#   'places_of_worship': {'ext_mosques_destroyed': 6,
#    'ext_mosques_damaged': 12,
#    'ext_churches_destroyed': 0},
#   'residential': {'destroyed': 790, 'ext_destroyed': 790}},
#  {'report_date': '2023-10-10',
#   'civic_buildings': {'ext_destroyed': 22},
#   'educational_buildings': {'ext_destroyed': 2, 'ext_damaged': 60},
#   'places_of_worship': {'ext_mosques_destroyed': 8,
#    'ext_mosques_damaged': 17,
#    'ext_churches_destroyed': 0},
#   'residential': {'destroyed': 1009, 'ext_destroyed': 1009}},
#  {'report_date': '2023-10-11',
#   'civic_buildings': {'destroyed': 27, 'ext_destroyed': 27},
#   'educational_buildings': {'destroyed': 3,
#    'ext_destroyed': 3,
#    'damaged': 75,
#    'ext_damaged': 75},
#   'places_of_worship': {'mosques_destroyed': 10,
#    'ext_mosques_destroyed': 10,
#    'ext_mosques_damaged': 21,
#    'ext_churches_destroyed': 0},
#   'residential': {'destroyed': 2835, 'ext_destroyed': 2835}},
#  {'report_date': '2023-10-12',
#   'civic_buildings': {'ext_destroyed': 29},
#   'educational_buildings': {'destroyed': 3,
#    'ext_destroyed': 3,
#    'damaged': 75,
#    'ext_damaged': 75},
#   'places_of_worship': {'mosques_destroyed': 10,
#    'ext_mosques_destroyed': 10,
#    'ext_mosques_damaged': 25,
#    'ext_churches_destroyed': 0},
#   'residential': {'ext_destroyed': 4188}},
#  {'report_date': '2023-10-13',
#   'civic_buildings': {'ext_destroyed': 31},
#   'educational_buildings': {'ext_destroyed': 9, 'ext_damaged': 100},
#   'places_of_worship': {'ext_mosques_destroyed': 12,
#    'ext_mosques_damaged': 29,
#    'ext_churches_destroyed': 0},
#   'residential': {'destroyed': 5540, 'ext_destroyed': 5540}},
#  {'report_date': '2023-10-14',
#   'civic_buildings': {'ext_destroyed': 33},
#   'educational_buildings': {'destroyed': 14,
#    'ext_destroyed': 14,
#    'damaged': 124,
#    'ext_damaged': 124},
#   'places_of_worship': {'ext_mosques_destroyed': 14,
#    'ext_mosques_damaged': 33,
#    'ext_churches_destroyed': 0},
#   'residential': {'destroyed': 7000, 'ext_destroyed': 7000}},
#  {'report_date': '2023-10-15',
#   'civic_buildings': {'ext_destroyed': 35},
#   'educational_buildings': {'destroyed': 14,
#    'ext_destroyed': 14,
#    'damaged': 143,
#    'ext_damaged': 143},
#   'places_of_worship': {'ext_mosques_destroyed': 16,
#    'ext_mosques_damaged': 37,
#    'ext_churches_destroyed': 0},
#   'residential': {'destroyed': 8840, 'ext_destroyed': 8840}},
#  {'report_date': '2023-10-16',
#   'civic_buildings': {'ext_destroyed': 37},
#   'educational_buildings': {'destroyed': 18,
#    'ext_destroyed': 18,
#    'damaged': 150,
#    'ext_damaged': 150},
#   'places_of_worship': {'ext_mosques_destroyed': 18,
#    'ext_mosques_damaged': 41,
#    'ext_churches_destroyed': 1},
#   'residential': {'destroyed': 10500, 'ext_destroyed': 10500}},
#  {'report_date': '2023-10-17',
#   'civic_buildings': {'ext_destroyed': 39},
#   'educational_buildings': {'destroyed': 18,
#    'ext_destroyed': 18,
#    'damaged': 153,
#    'ext_damaged': 153},
#   'places_of_worship': {'ext_mosques_destroyed': 20,
#    'ext_mosques_damaged': 46,
#    'ext_churches_destroyed': 1},
#   'residential': {'destroyed': 12000, 'ext_destroyed': 12000}},
#  {'report_date': '2023-10-18',
#   'civic_buildings': {'ext_destroyed': 41},
#   'educational_buildings': {'ext_destroyed': 20, 'ext_damaged': 157},
#   'places_of_worship': {'ext_mosques_destroyed': 22,
#    'ext_mosques_damaged': 50,
#    'ext_churches_destroyed': 1},
#   'residential': {'ext_destroyed': 13577}},
#  {'report_date': '2023-10-19',
#   'civic_buildings': {'ext_destroyed': 43},
#   'educational_buildings': {'ext_destroyed': 22, 'ext_damaged': 160},
#   'places_of_worship': {'ext_mosques_destroyed': 24,
#    'ext_mosques_damaged': 54,
#    'ext_churches_destroyed': 1},
#   'residential': {'ext_destroyed': 15154}},
#  {'report_date': '2023-10-20',
#   'civic_buildings': {'ext_destroyed': 45},
#   'educational_buildings': {'ext_destroyed': 23, 'ext_damaged': 164},
#   'places_of_worship': {'ext_mosques_destroyed': 26,
#    'ext_mosques_damaged': 58,
#    'ext_churches_destroyed': 1},
#   'residential': {'ext_destroyed': 16731}},
#  {'report_date': '2023-10-21',
#   'civic_buildings': {'ext_destroyed': 47},
#   'educational_buildings': {'ext_destroyed': 25, 'ext_damaged': 167},
#   'places_of_worship': {'ext_mosques_destroyed': 28,
#    'ext_mosques_damaged': 62,
#    'ext_churches_destroyed': 1},
#   'residential': {'ext_destroyed': 18308}},
#  {'report_date': '2023-10-22',
#   'civic_buildings': {'ext_destroyed': 49},
#   'educational_buildings': {'ext_destroyed': 27, 'ext_damaged': 171},
#   'places_of_worship': {'ext_mosques_destroyed': 30,
#    'ext_mosques_damaged': 66,
#    'ext_churches_destroyed': 1},
#   'residential': {'ext_destroyed': 19885}},
#  {'report_date': '2023-10-23',
#   'civic_buildings': {'ext_destroyed': 51},
#   'educational_buildings': {'ext_destroyed': 29, 'ext_damaged': 174},
#   'places_of_worship': {'ext_mosques_destroyed': 32,
#    'ext_mosques_damaged': 70,
#    'ext_churches_destroyed': 1},
#   'residential': {'ext_destroyed': 21462}},
#  {'report_date': '2023-10-24',
#   'civic_buildings': {'ext_destroyed': 53},
#   'educational_buildings': {'ext_destroyed': 30, 'ext_damaged': 178},
#   'places_of_worship': {'ext_mosques_destroyed': 34,
#    'ext_mosques_damaged': 75,
#    'ext_churches_destroyed': 1},
#   'residential': {'ext_destroyed': 23038}},
#  {'report_date': '2023-10-25',
#   'civic_buildings': {'ext_destroyed': 55},
#   'educational_buildings': {'ext_destroyed': 32, 'ext_damaged': 181},
#   'places_of_worship': {'ext_mosques_destroyed': 36,
#    'ext_mosques_damaged': 79,
#    'ext_churches_destroyed': 1},
#   'residential': {'ext_destroyed': 24615}},
#  {'report_date': '2023-10-26',
#   'civic_buildings': {'ext_destroyed': 57},
#   'educational_buildings': {'ext_destroyed': 34, 'ext_damaged': 185},
#   'places_of_worship': {'ext_mosques_destroyed': 38,
#    'ext_mosques_damaged': 83,
#    'ext_churches_destroyed': 1},
#   'residential': {'ext_destroyed': 26192}},
#  {'report_date': '2023-10-27',
#   'civic_buildings': {'ext_destroyed': 59},
#   'educational_buildings': {'ext_destroyed': 36, 'ext_damaged': 188},
#   'places_of_worship': {'ext_mosques_destroyed': 39,
#    'ext_mosques_damaged': 87,
#    'ext_churches_destroyed': 1},
#   'residential': {'ext_destroyed': 27769}},
#  {'report_date': '2023-10-28',
#   'civic_buildings': {'ext_destroyed': 60},
#   'educational_buildings': {'ext_destroyed': 37, 'ext_damaged': 192},
#   'places_of_worship': {'ext_mosques_destroyed': 41,
#    'ext_mosques_damaged': 91,
#    'ext_churches_destroyed': 1},
#   'residential': {'ext_destroyed': 29346}},
#  {'report_date': '2023-10-29',
#   'civic_buildings': {'ext_destroyed': 62},
#   'educational_buildings': {'ext_destroyed': 39, 'ext_damaged': 196},
#   'places_of_worship': {'ext_mosques_destroyed': 43,
#    'ext_mosques_damaged': 95,
#    'ext_churches_destroyed': 1},
#   'residential': {'ext_destroyed': 30923}},
#  {'report_date': '2023-10-30',
#   'civic_buildings': {'ext_destroyed': 64},
#   'educational_buildings': {'ext_destroyed': 41, 'ext_damaged': 199},
#   'places_of_worship': {'ext_mosques_destroyed': 45,
#    'ext_mosques_damaged': 99,
#    'ext_churches_destroyed': 1},
#   'residential': {'destroyed': 32500, 'ext_destroyed': 32500}},
#  {'report_date': '2023-10-31',
#   'civic_buildings': {'ext_destroyed': 66},
#   'educational_buildings': {'ext_destroyed': 43, 'ext_damaged': 203},
#   'places_of_worship': {'ext_mosques_destroyed': 47,
#    'ext_mosques_damaged': 104,
#    'ext_churches_destroyed': 1},
#   'residential': {'ext_destroyed': 33571}},
#  {'report_date': '2023-11-01',
#   'civic_buildings': {'ext_destroyed': 68},
#   'educational_buildings': {'ext_destroyed': 44, 'ext_damaged': 206},
#   'places_of_worship': {'ext_mosques_destroyed': 49,
#    'ext_mosques_damaged': 108,
#    'ext_churches_destroyed': 1},
#   'residential': {'ext_destroyed': 34643}},
#  {'report_date': '2023-11-02',
#   'civic_buildings': {'ext_destroyed': 70},
#   'educational_buildings': {'ext_destroyed': 46, 'ext_damaged': 210},
#   'places_of_worship': {'ext_mosques_destroyed': 51,
#    'ext_mosques_damaged': 112,
#    'ext_churches_destroyed': 1},
#   'residential': {'ext_destroyed': 35714}},
#  {'report_date': '2023-11-03',
#   'civic_buildings': {'ext_destroyed': 72},
#   'educational_buildings': {'ext_destroyed': 48, 'ext_damaged': 213},
#   'places_of_worship': {'ext_mosques_destroyed': 53,
#    'ext_mosques_damaged': 116,
#    'ext_churches_destroyed': 1},
#   'residential': {'ext_destroyed': 36786}},
#  {'report_date': '2023-11-04',
#   'civic_buildings': {'ext_destroyed': 74},
#   'educational_buildings': {'ext_destroyed': 50, 'ext_damaged': 217},
#   'places_of_worship': {'ext_mosques_destroyed': 55,
#    'ext_mosques_damaged': 120,
#    'ext_churches_destroyed': 2},
#   'residential': {'ext_destroyed': 37857}},
#  {'report_date': '2023-11-05',
#   'civic_buildings': {'ext_destroyed': 76},
#   'educational_buildings': {'ext_destroyed': 51, 'ext_damaged': 220},
#   'places_of_worship': {'ext_mosques_destroyed': 57,
#    'ext_mosques_damaged': 124,
#    'ext_churches_destroyed': 2},
#   'residential': {'ext_destroyed': 38929}},
#  {'report_date': '2023-11-06',
#   'civic_buildings': {'ext_destroyed': 78},
#   'educational_buildings': {'ext_destroyed': 53, 'ext_damaged': 224},
#   'places_of_worship': {'ext_mosques_destroyed': 59,
#    'ext_mosques_damaged': 128,
#    'ext_churches_destroyed': 2},
#   'residential': {'destroyed': 40000, 'ext_destroyed': 40000}},
#  {'report_date': '2023-11-07',
#   'civic_buildings': {'ext_destroyed': 80},
#   'educational_buildings': {'ext_destroyed': 55, 'ext_damaged': 227},
#   'places_of_worship': {'ext_mosques_destroyed': 61,
#    'ext_mosques_damaged': 133,
#    'ext_churches_destroyed': 2},
#   'residential': {'ext_destroyed': 40250}},
#  {'report_date': '2023-11-08',
#   'civic_buildings': {'ext_destroyed': 82},
#   'educational_buildings': {'ext_destroyed': 57, 'ext_damaged': 231},
#   'places_of_worship': {'ext_mosques_destroyed': 63,
#    'ext_mosques_damaged': 137,
#    'ext_churches_destroyed': 2},
#   'residential': {'ext_destroyed': 40500}},
#  {'report_date': '2023-11-09',
#   'civic_buildings': {'ext_destroyed': 84},
#   'educational_buildings': {'ext_destroyed': 58, 'ext_damaged': 234},
#   'places_of_worship': {'ext_mosques_destroyed': 65,
#    'ext_mosques_damaged': 141,
#    'ext_churches_destroyed': 2},
#   'residential': {'ext_destroyed': 40750}},
#  {'report_date': '2023-11-10',
#   'civic_buildings': {'destroyed': 88, 'ext_destroyed': 88},
#   'educational_buildings': {'destroyed': 60,
#    'ext_destroyed': 60,
#    'damaged': 238,
#    'ext_damaged': 238},
#   'places_of_worship': {'mosques_destroyed': 67,
#    'ext_mosques_destroyed': 67,
#    'mosques_damaged': 145,
#    'ext_mosques_damaged': 145,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 2},
#   'residential': {'destroyed': 41000, 'ext_destroyed': 41000}},
#  {'report_date': '2023-11-11',
#   'civic_buildings': {'ext_destroyed': 89},
#   'educational_buildings': {'ext_destroyed': 60, 'ext_damaged': 239},
#   'places_of_worship': {'ext_mosques_destroyed': 68,
#    'ext_mosques_damaged': 146,
#    'ext_churches_destroyed': 2},
#   'residential': {'ext_destroyed': 41015}},
#  {'report_date': '2023-11-12',
#   'civic_buildings': {'ext_destroyed': 89},
#   'educational_buildings': {'ext_destroyed': 61, 'ext_damaged': 241},
#   'places_of_worship': {'ext_mosques_destroyed': 70,
#    'ext_mosques_damaged': 148,
#    'ext_churches_destroyed': 2},
#   'residential': {'destroyed': 41030, 'ext_destroyed': 41030}},
#  {'report_date': '2023-11-13',
#   'civic_buildings': {'ext_destroyed': 90},
#   'educational_buildings': {'ext_destroyed': 61, 'ext_damaged': 242},
#   'places_of_worship': {'ext_mosques_destroyed': 71,
#    'ext_mosques_damaged': 149,
#    'ext_churches_destroyed': 2},
#   'residential': {'destroyed': 41120, 'ext_destroyed': 41120}},
#  {'report_date': '2023-11-14',
#   'civic_buildings': {'ext_destroyed': 91},
#   'educational_buildings': {'ext_destroyed': 61, 'ext_damaged': 243},
#   'places_of_worship': {'ext_mosques_destroyed': 72,
#    'ext_mosques_damaged': 151,
#    'ext_churches_destroyed': 2},
#   'residential': {'destroyed': 42000, 'ext_destroyed': 42000}},
#  {'report_date': '2023-11-15',
#   'civic_buildings': {'ext_destroyed': 91},
#   'educational_buildings': {'ext_destroyed': 62, 'ext_damaged': 245},
#   'places_of_worship': {'ext_mosques_destroyed': 74,
#    'ext_mosques_damaged': 152,
#    'ext_churches_destroyed': 2},
#   'residential': {'ext_destroyed': 42250}},
#  {'report_date': '2023-11-16',
#   'civic_buildings': {'ext_destroyed': 92},
#   'educational_buildings': {'ext_destroyed': 62, 'ext_damaged': 246},
#   'places_of_worship': {'ext_mosques_destroyed': 75,
#    'ext_mosques_damaged': 154,
#    'ext_churches_destroyed': 2},
#   'residential': {'ext_destroyed': 42500}},
#  {'report_date': '2023-11-17',
#   'civic_buildings': {'ext_destroyed': 93},
#   'educational_buildings': {'ext_destroyed': 62, 'ext_damaged': 247},
#   'places_of_worship': {'ext_mosques_destroyed': 76,
#    'ext_mosques_damaged': 155,
#    'ext_churches_destroyed': 2},
#   'residential': {'ext_destroyed': 42750}},
#  {'report_date': '2023-11-18',
#   'civic_buildings': {'ext_destroyed': 93},
#   'educational_buildings': {'ext_destroyed': 63, 'ext_damaged': 249},
#   'places_of_worship': {'ext_mosques_destroyed': 78,
#    'ext_mosques_damaged': 156,
#    'ext_churches_destroyed': 2},
#   'residential': {'destroyed': 43000, 'ext_destroyed': 43000}},
#  {'report_date': '2023-11-19',
#   'civic_buildings': {'ext_destroyed': 94},
#   'educational_buildings': {'ext_destroyed': 63, 'ext_damaged': 250},
#   'places_of_worship': {'ext_mosques_destroyed': 79,
#    'ext_mosques_damaged': 158,
#    'ext_churches_destroyed': 2},
#   'residential': {'destroyed': 43000, 'ext_destroyed': 43000}},
#  {'report_date': '2023-11-20',
#   'civic_buildings': {'ext_destroyed': 95},
#   'educational_buildings': {'ext_destroyed': 63, 'ext_damaged': 251},
#   'places_of_worship': {'ext_mosques_destroyed': 80,
#    'ext_mosques_damaged': 159,
#    'ext_churches_destroyed': 2},
#   'residential': {'destroyed': 43000, 'ext_destroyed': 43000}},
#  {'report_date': '2023-11-21',
#   'civic_buildings': {'ext_destroyed': 96},
#   'educational_buildings': {'ext_destroyed': 63, 'ext_damaged': 253},
#   'places_of_worship': {'ext_mosques_destroyed': 82,
#    'ext_mosques_damaged': 161,
#    'ext_churches_destroyed': 2},
#   'residential': {'destroyed': 44000, 'ext_destroyed': 44000}},
#  {'report_date': '2023-11-22',
#   'civic_buildings': {'ext_destroyed': 96},
#   'educational_buildings': {'ext_destroyed': 64, 'ext_damaged': 254},
#   'places_of_worship': {'ext_mosques_destroyed': 83,
#    'ext_mosques_damaged': 162,
#    'ext_churches_destroyed': 2},
#   'residential': {'destroyed': 45000, 'ext_destroyed': 45000}},
#  {'report_date': '2023-11-23',
#   'civic_buildings': {'ext_destroyed': 97},
#   'educational_buildings': {'ext_destroyed': 64, 'ext_damaged': 255},
#   'places_of_worship': {'ext_mosques_destroyed': 84,
#    'ext_mosques_damaged': 164,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 46000, 'ext_destroyed': 46000}},
#  {'report_date': '2023-11-24',
#   'civic_buildings': {'ext_destroyed': 98},
#   'educational_buildings': {'ext_destroyed': 64, 'ext_damaged': 256},
#   'places_of_worship': {'ext_mosques_destroyed': 86,
#    'ext_mosques_damaged': 165,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 47000}},
#  {'report_date': '2023-11-25',
#   'civic_buildings': {'ext_destroyed': 98},
#   'educational_buildings': {'ext_destroyed': 65, 'ext_damaged': 258},
#   'places_of_worship': {'ext_mosques_destroyed': 87,
#    'ext_mosques_damaged': 166,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 48000}},
#  {'report_date': '2023-11-26',
#   'civic_buildings': {'ext_destroyed': 99},
#   'educational_buildings': {'ext_destroyed': 65, 'ext_damaged': 259},
#   'places_of_worship': {'ext_mosques_destroyed': 89,
#    'ext_mosques_damaged': 168,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 49000}},
#  {'report_date': '2023-11-27',
#   'civic_buildings': {'ext_destroyed': 100},
#   'educational_buildings': {'ext_destroyed': 65, 'ext_damaged': 260},
#   'places_of_worship': {'ext_mosques_destroyed': 90,
#    'ext_mosques_damaged': 169,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 50000, 'ext_destroyed': 50000}},
#  {'report_date': '2023-11-28',
#   'civic_buildings': {'ext_destroyed': 100},
#   'educational_buildings': {'ext_destroyed': 66, 'ext_damaged': 262},
#   'places_of_worship': {'ext_mosques_destroyed': 91,
#    'ext_mosques_damaged': 171,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 50000}},
#  {'report_date': '2023-11-29',
#   'civic_buildings': {'ext_destroyed': 101},
#   'educational_buildings': {'ext_destroyed': 66, 'ext_damaged': 263},
#   'places_of_worship': {'ext_mosques_destroyed': 93,
#    'ext_mosques_damaged': 172,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 50000}},
#  {'report_date': '2023-11-30',
#   'civic_buildings': {'ext_destroyed': 102},
#   'educational_buildings': {'ext_destroyed': 66, 'ext_damaged': 264},
#   'places_of_worship': {'ext_mosques_destroyed': 94,
#    'ext_mosques_damaged': 174,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 50000, 'ext_destroyed': 50000}},
#  {'report_date': '2023-12-01',
#   'civic_buildings': {'destroyed': 103, 'ext_destroyed': 103},
#   'educational_buildings': {'ext_destroyed': 67,
#    'damaged': 267,
#    'ext_damaged': 267},
#   'places_of_worship': {'ext_mosques_destroyed': 95,
#    'mosques_damaged': 175,
#    'ext_mosques_damaged': 175,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 50000, 'ext_destroyed': 50000}},
#  {'report_date': '2023-12-02',
#   'civic_buildings': {'ext_destroyed': 103},
#   'educational_buildings': {'destroyed': 67,
#    'ext_destroyed': 67,
#    'damaged': 267,
#    'ext_damaged': 267},
#   'places_of_worship': {'ext_mosques_destroyed': 97,
#    'mosques_damaged': 181,
#    'ext_mosques_damaged': 181,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 50000, 'ext_destroyed': 50000}},
#  {'report_date': '2023-12-03',
#   'civic_buildings': {'destroyed': 103, 'ext_destroyed': 103},
#   'educational_buildings': {'destroyed': 67,
#    'ext_destroyed': 67,
#    'damaged': 270,
#    'ext_damaged': 270},
#   'places_of_worship': {'ext_mosques_destroyed': 98,
#    'mosques_damaged': 183,
#    'ext_mosques_damaged': 183,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 50000, 'ext_destroyed': 50000}},
#  {'report_date': '2023-12-04',
#   'civic_buildings': {'ext_destroyed': 107},
#   'educational_buildings': {'ext_destroyed': 69, 'ext_damaged': 271},
#   'places_of_worship': {'ext_mosques_destroyed': 99,
#    'ext_mosques_damaged': 186,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 51000}},
#  {'report_date': '2023-12-05',
#   'civic_buildings': {'ext_destroyed': 110},
#   'educational_buildings': {'ext_destroyed': 70, 'ext_damaged': 273},
#   'places_of_worship': {'ext_mosques_destroyed': 101,
#    'ext_mosques_damaged': 189,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 52000, 'ext_destroyed': 52000}},
#  {'report_date': '2023-12-06',
#   'civic_buildings': {'ext_destroyed': 114},
#   'educational_buildings': {'ext_destroyed': 72, 'ext_damaged': 274},
#   'places_of_worship': {'ext_mosques_destroyed': 102,
#    'ext_mosques_damaged': 191,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 52000}},
#  {'report_date': '2023-12-07',
#   'civic_buildings': {'destroyed': 121, 'ext_destroyed': 121},
#   'educational_buildings': {'destroyed': 73,
#    'ext_destroyed': 73,
#    'damaged': 275,
#    'ext_damaged': 275},
#   'places_of_worship': {'ext_mosques_destroyed': 103,
#    'mosques_damaged': 194,
#    'ext_mosques_damaged': 194,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 52000, 'ext_destroyed': 52000}},
#  {'report_date': '2023-12-08',
#   'civic_buildings': {'ext_destroyed': 122},
#   'educational_buildings': {'ext_destroyed': 73, 'ext_damaged': 275},
#   'places_of_worship': {'ext_mosques_destroyed': 105,
#    'ext_mosques_damaged': 194,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 52100}},
#  {'report_date': '2023-12-09',
#   'civic_buildings': {'ext_destroyed': 123},
#   'educational_buildings': {'ext_destroyed': 74, 'ext_damaged': 276},
#   'places_of_worship': {'ext_mosques_destroyed': 106,
#    'ext_mosques_damaged': 195,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 52200}},
#  {'report_date': '2023-12-10',
#   'civic_buildings': {'ext_destroyed': 124},
#   'educational_buildings': {'ext_destroyed': 74, 'ext_damaged': 276},
#   'places_of_worship': {'ext_mosques_destroyed': 107,
#    'ext_mosques_damaged': 195,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 52300}},
#  {'report_date': '2023-12-11',
#   'civic_buildings': {'ext_destroyed': 124},
#   'educational_buildings': {'ext_destroyed': 75, 'ext_damaged': 276},
#   'places_of_worship': {'ext_mosques_destroyed': 109,
#    'ext_mosques_damaged': 196,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 52400}},
#  {'report_date': '2023-12-12',
#   'civic_buildings': {'destroyed': 126, 'ext_destroyed': 126},
#   'educational_buildings': {'destroyed': 75,
#    'ext_destroyed': 75,
#    'damaged': 277,
#    'ext_damaged': 277},
#   'places_of_worship': {'mosques_destroyed': 110,
#    'ext_mosques_destroyed': 110,
#    'mosques_damaged': 196,
#    'ext_mosques_damaged': 196,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 52500, 'ext_destroyed': 52500}},
#  {'report_date': '2023-12-13',
#   'civic_buildings': {'ext_destroyed': 126},
#   'educational_buildings': {'ext_destroyed': 80, 'ext_damaged': 278},
#   'places_of_worship': {'ext_mosques_destroyed': 111,
#    'ext_mosques_damaged': 197,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 52500}},
#  {'report_date': '2023-12-14',
#   'civic_buildings': {'ext_destroyed': 126},
#   'educational_buildings': {'ext_destroyed': 85, 'ext_damaged': 280},
#   'places_of_worship': {'ext_mosques_destroyed': 111,
#    'ext_mosques_damaged': 199,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 52500}},
#  {'report_date': '2023-12-15',
#   'civic_buildings': {'destroyed': 126, 'ext_destroyed': 126},
#   'educational_buildings': {'destroyed': 90,
#    'ext_destroyed': 90,
#    'damaged': 282,
#    'ext_damaged': 282},
#   'places_of_worship': {'mosques_destroyed': 112,
#    'ext_mosques_destroyed': 112,
#    'mosques_damaged': 200,
#    'ext_mosques_damaged': 200,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 52500, 'ext_destroyed': 52500}},
#  {'report_date': '2023-12-16',
#   'civic_buildings': {'ext_destroyed': 126},
#   'educational_buildings': {'ext_destroyed': 90, 'ext_damaged': 282},
#   'places_of_worship': {'ext_mosques_destroyed': 112,
#    'ext_mosques_damaged': 200,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 52500}},
#  {'report_date': '2023-12-17',
#   'civic_buildings': {'ext_destroyed': 126},
#   'educational_buildings': {'ext_destroyed': 90, 'ext_damaged': 282},
#   'places_of_worship': {'ext_mosques_destroyed': 112,
#    'ext_mosques_damaged': 200,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 52500}},
#  {'report_date': '2023-12-18',
#   'civic_buildings': {'destroyed': 126, 'ext_destroyed': 126},
#   'educational_buildings': {'destroyed': 90,
#    'ext_destroyed': 90,
#    'damaged': 282,
#    'ext_damaged': 282},
#   'places_of_worship': {'mosques_destroyed': 112,
#    'ext_mosques_destroyed': 112,
#    'mosques_damaged': 200,
#    'ext_mosques_damaged': 200,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 52500, 'ext_destroyed': 52500}},
#  {'report_date': '2023-12-19',
#   'civic_buildings': {'destroyed': 126, 'ext_destroyed': 126},
#   'educational_buildings': {'destroyed': 90,
#    'ext_destroyed': 90,
#    'damaged': 282,
#    'ext_damaged': 282},
#   'places_of_worship': {'mosques_destroyed': 112,
#    'ext_mosques_destroyed': 112,
#    'mosques_damaged': 200,
#    'ext_mosques_damaged': 200,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 52600, 'ext_destroyed': 52600}},
#  {'report_date': '2023-12-20',
#   'civic_buildings': {'destroyed': 126, 'ext_destroyed': 126},
#   'educational_buildings': {'destroyed': 90,
#    'ext_destroyed': 90,
#    'damaged': 283,
#    'ext_damaged': 283},
#   'places_of_worship': {'mosques_destroyed': 114,
#    'ext_mosques_destroyed': 114,
#    'mosques_damaged': 200,
#    'ext_mosques_damaged': 200,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 53000, 'ext_destroyed': 53000}},
#  {'report_date': '2023-12-21',
#   'civic_buildings': {'ext_destroyed': 126},
#   'educational_buildings': {'ext_destroyed': 91, 'ext_damaged': 284},
#   'places_of_worship': {'ext_mosques_destroyed': 114,
#    'ext_mosques_damaged': 200,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 55400}},
#  {'report_date': '2023-12-22',
#   'civic_buildings': {'ext_destroyed': 126},
#   'educational_buildings': {'ext_destroyed': 91, 'ext_damaged': 284},
#   'places_of_worship': {'ext_mosques_destroyed': 115,
#    'ext_mosques_damaged': 200,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 57800}},
#  {'report_date': '2023-12-23',
#   'civic_buildings': {'destroyed': 126, 'ext_destroyed': 126},
#   'educational_buildings': {'destroyed': 92,
#    'ext_destroyed': 92,
#    'damaged': 285,
#    'ext_damaged': 285},
#   'places_of_worship': {'mosques_destroyed': 115,
#    'ext_mosques_destroyed': 115,
#    'mosques_damaged': 200,
#    'ext_mosques_damaged': 200,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 60200}},
#  {'report_date': '2023-12-24',
#   'civic_buildings': {'ext_destroyed': 126},
#   'educational_buildings': {'ext_destroyed': 92, 'ext_damaged': 285},
#   'places_of_worship': {'ext_mosques_destroyed': 115,
#    'ext_mosques_damaged': 200,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 62600}},
#  {'report_date': '2023-12-25',
#   'civic_buildings': {'destroyed': 126, 'ext_destroyed': 126},
#   'educational_buildings': {'destroyed': 92,
#    'ext_destroyed': 92,
#    'damaged': 285,
#    'ext_damaged': 285},
#   'places_of_worship': {'mosques_destroyed': 115,
#    'ext_mosques_destroyed': 115,
#    'mosques_damaged': 200,
#    'ext_mosques_damaged': 200,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 65000, 'ext_destroyed': 65000}},
#  {'report_date': '2023-12-26',
#   'civic_buildings': {'ext_destroyed': 126},
#   'educational_buildings': {'ext_destroyed': 92, 'ext_damaged': 285},
#   'places_of_worship': {'ext_mosques_destroyed': 115,
#    'ext_mosques_damaged': 200,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 65000}},
#  {'report_date': '2023-12-27',
#   'civic_buildings': {'destroyed': 126, 'ext_destroyed': 126},
#   'educational_buildings': {'destroyed': 92,
#    'ext_destroyed': 92,
#    'damaged': 285,
#    'ext_damaged': 285},
#   'places_of_worship': {'mosques_destroyed': 115,
#    'ext_mosques_destroyed': 115,
#    'mosques_damaged': 200,
#    'ext_mosques_damaged': 200,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 65000, 'ext_destroyed': 65000}},
#  {'report_date': '2023-12-28',
#   'civic_buildings': {'ext_destroyed': 126},
#   'educational_buildings': {'ext_destroyed': 92, 'ext_damaged': 285},
#   'places_of_worship': {'ext_mosques_destroyed': 116,
#    'ext_mosques_damaged': 203,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 65000}},
#  {'report_date': '2023-12-29',
#   'civic_buildings': {'ext_destroyed': 126},
#   'educational_buildings': {'ext_destroyed': 92, 'ext_damaged': 285},
#   'places_of_worship': {'ext_mosques_destroyed': 116,
#    'ext_mosques_damaged': 205,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 65000}},
#  {'report_date': '2023-12-30',
#   'civic_buildings': {'destroyed': 126, 'ext_destroyed': 126},
#   'educational_buildings': {'destroyed': 92,
#    'ext_destroyed': 92,
#    'damaged': 285,
#    'ext_damaged': 285},
#   'places_of_worship': {'mosques_destroyed': 117,
#    'ext_mosques_destroyed': 117,
#    'mosques_damaged': 208,
#    'ext_mosques_damaged': 208,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 65000, 'ext_destroyed': 65000}},
#  {'report_date': '2023-12-31',
#   'civic_buildings': {'destroyed': 126, 'ext_destroyed': 126},
#   'educational_buildings': {'destroyed': 92,
#    'ext_destroyed': 92,
#    'damaged': 285,
#    'ext_damaged': 285},
#   'places_of_worship': {'mosques_destroyed': 119,
#    'ext_mosques_destroyed': 119,
#    'mosques_damaged': 212,
#    'ext_mosques_damaged': 212,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 65000, 'ext_destroyed': 65000}},
#  {'report_date': '2024-01-01',
#   'civic_buildings': {'destroyed': 130, 'ext_destroyed': 130},
#   'educational_buildings': {'destroyed': 93,
#    'ext_destroyed': 93,
#    'damaged': 292,
#    'ext_damaged': 292},
#   'places_of_worship': {'mosques_destroyed': 120,
#    'ext_mosques_destroyed': 120,
#    'mosques_damaged': 212,
#    'ext_mosques_damaged': 212,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 65000, 'ext_destroyed': 65000}},
#  {'report_date': '2024-01-02',
#   'civic_buildings': {'ext_destroyed': 130},
#   'educational_buildings': {'ext_destroyed': 93, 'ext_damaged': 292},
#   'places_of_worship': {'ext_mosques_destroyed': 121,
#    'ext_mosques_damaged': 214,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 65000}},
#  {'report_date': '2024-01-03',
#   'civic_buildings': {'ext_destroyed': 130},
#   'educational_buildings': {'ext_destroyed': 93, 'ext_damaged': 292},
#   'places_of_worship': {'ext_mosques_destroyed': 121,
#    'ext_mosques_damaged': 216,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 65000}},
#  {'report_date': '2024-01-04',
#   'civic_buildings': {'destroyed': 130, 'ext_destroyed': 130},
#   'educational_buildings': {'destroyed': 93,
#    'ext_destroyed': 93,
#    'damaged': 292,
#    'ext_damaged': 292},
#   'places_of_worship': {'mosques_destroyed': 122,
#    'ext_mosques_destroyed': 122,
#    'mosques_damaged': 218,
#    'ext_mosques_damaged': 218,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 65000, 'ext_destroyed': 65000}},
#  {'report_date': '2024-01-05',
#   'civic_buildings': {'ext_destroyed': 132},
#   'educational_buildings': {'ext_destroyed': 94, 'ext_damaged': 294},
#   'places_of_worship': {'ext_mosques_destroyed': 126,
#    'ext_mosques_damaged': 229,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 67000}},
#  {'report_date': '2024-01-06',
#   'civic_buildings': {'destroyed': 134, 'ext_destroyed': 134},
#   'educational_buildings': {'destroyed': 94,
#    'ext_destroyed': 94,
#    'damaged': 295,
#    'ext_damaged': 295},
#   'places_of_worship': {'mosques_destroyed': 130,
#    'ext_mosques_destroyed': 130,
#    'mosques_damaged': 240,
#    'ext_mosques_damaged': 240,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 69000, 'ext_destroyed': 69000}},
#  {'report_date': '2024-01-07',
#   'civic_buildings': {'destroyed': 134, 'ext_destroyed': 134},
#   'educational_buildings': {'destroyed': 94,
#    'ext_destroyed': 94,
#    'damaged': 295,
#    'ext_damaged': 295},
#   'places_of_worship': {'mosques_destroyed': 134,
#    'ext_mosques_destroyed': 134,
#    'mosques_damaged': 240,
#    'ext_mosques_damaged': 240,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 69000, 'ext_destroyed': 69000}},
#  {'report_date': '2024-01-08',
#   'civic_buildings': {'ext_destroyed': 134},
#   'educational_buildings': {'ext_destroyed': 95, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 138,
#    'ext_mosques_damaged': 240,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 69000}},
#  {'report_date': '2024-01-09',
#   'civic_buildings': {'destroyed': 134, 'ext_destroyed': 134},
#   'educational_buildings': {'destroyed': 95,
#    'ext_destroyed': 95,
#    'damaged': 295,
#    'ext_damaged': 295},
#   'places_of_worship': {'mosques_destroyed': 142,
#    'ext_mosques_destroyed': 142,
#    'mosques_damaged': 240,
#    'ext_mosques_damaged': 240,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 69000, 'ext_destroyed': 69000}},
#  {'report_date': '2024-01-10',
#   'civic_buildings': {'ext_destroyed': 134},
#   'educational_buildings': {'ext_destroyed': 95, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 142,
#    'ext_mosques_damaged': 240,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 69100}},
#  {'report_date': '2024-01-11',
#   'civic_buildings': {'destroyed': 134, 'ext_destroyed': 134},
#   'educational_buildings': {'destroyed': 95,
#    'ext_destroyed': 95,
#    'damaged': 295,
#    'ext_damaged': 295},
#   'places_of_worship': {'mosques_destroyed': 142,
#    'ext_mosques_destroyed': 142,
#    'mosques_damaged': 240,
#    'ext_mosques_damaged': 240,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 69200, 'ext_destroyed': 69200}},
#  {'report_date': '2024-01-12',
#   'civic_buildings': {'ext_destroyed': 134},
#   'educational_buildings': {'ext_destroyed': 95, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 145,
#    'ext_mosques_damaged': 242,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 69250}},
#  {'report_date': '2024-01-13',
#   'civic_buildings': {'ext_destroyed': 134},
#   'educational_buildings': {'ext_destroyed': 95, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 147,
#    'ext_mosques_damaged': 243,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 69300, 'ext_destroyed': 69300}},
#  {'report_date': '2024-01-14',
#   'civic_buildings': {'destroyed': 134, 'ext_destroyed': 134},
#   'educational_buildings': {'destroyed': 95,
#    'ext_destroyed': 95,
#    'damaged': 295,
#    'ext_damaged': 295},
#   'places_of_worship': {'mosques_destroyed': 150,
#    'ext_mosques_destroyed': 150,
#    'mosques_damaged': 245,
#    'ext_mosques_damaged': 245,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 70000, 'ext_destroyed': 70000}},
#  {'report_date': '2024-01-15',
#   'civic_buildings': {'ext_destroyed': 135},
#   'educational_buildings': {'ext_destroyed': 96, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 152,
#    'ext_mosques_damaged': 245,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-01-16',
#   'civic_buildings': {'ext_destroyed': 136},
#   'educational_buildings': {'ext_destroyed': 96, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 154,
#    'ext_mosques_damaged': 246,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-01-17',
#   'civic_buildings': {'ext_destroyed': 137},
#   'educational_buildings': {'ext_destroyed': 97, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 155,
#    'ext_mosques_damaged': 246,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-01-18',
#   'civic_buildings': {'destroyed': 138, 'ext_destroyed': 138},
#   'educational_buildings': {'destroyed': 97,
#    'ext_destroyed': 97,
#    'damaged': 295,
#    'ext_damaged': 295},
#   'places_of_worship': {'mosques_destroyed': 157,
#    'ext_mosques_destroyed': 157,
#    'mosques_damaged': 246,
#    'ext_mosques_damaged': 246,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 70000, 'ext_destroyed': 70000}},
#  {'report_date': '2024-01-19',
#   'civic_buildings': {'ext_destroyed': 139},
#   'educational_buildings': {'ext_destroyed': 98, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 158,
#    'ext_mosques_damaged': 248,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-01-20',
#   'civic_buildings': {'ext_destroyed': 139},
#   'educational_buildings': {'ext_destroyed': 98, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 159,
#    'ext_mosques_damaged': 250,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-01-21',
#   'civic_buildings': {'ext_destroyed': 140},
#   'educational_buildings': {'ext_destroyed': 99, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 160,
#    'ext_mosques_damaged': 251,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-01-22',
#   'civic_buildings': {'destroyed': 140, 'ext_destroyed': 140},
#   'educational_buildings': {'destroyed': 99,
#    'ext_destroyed': 99,
#    'damaged': 295,
#    'ext_damaged': 295},
#   'places_of_worship': {'mosques_destroyed': 161,
#    'ext_mosques_destroyed': 161,
#    'mosques_damaged': 253,
#    'ext_mosques_damaged': 253,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 70000, 'ext_destroyed': 70000}},
#  {'report_date': '2024-01-23',
#   'civic_buildings': {'ext_destroyed': 140},
#   'educational_buildings': {'ext_destroyed': 99, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 161,
#    'ext_mosques_damaged': 253,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-01-24',
#   'civic_buildings': {'ext_destroyed': 140},
#   'educational_buildings': {'ext_destroyed': 99, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 161,
#    'ext_mosques_damaged': 253,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-01-25',
#   'civic_buildings': {'ext_destroyed': 140},
#   'educational_buildings': {'ext_destroyed': 99, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 161,
#    'ext_mosques_damaged': 253,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-01-26',
#   'civic_buildings': {'ext_destroyed': 140},
#   'educational_buildings': {'ext_destroyed': 99, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 161,
#    'ext_mosques_damaged': 253,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-01-27',
#   'civic_buildings': {'ext_destroyed': 140},
#   'educational_buildings': {'ext_destroyed': 99, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 161,
#    'ext_mosques_damaged': 253,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-01-28',
#   'civic_buildings': {'ext_destroyed': 140},
#   'educational_buildings': {'ext_destroyed': 99, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 161,
#    'ext_mosques_damaged': 253,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-01-29',
#   'civic_buildings': {'ext_destroyed': 140},
#   'educational_buildings': {'ext_destroyed': 99, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 161,
#    'ext_mosques_damaged': 253,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-01-30',
#   'civic_buildings': {'destroyed': 140, 'ext_destroyed': 140},
#   'educational_buildings': {'destroyed': 99,
#    'ext_destroyed': 99,
#    'damaged': 295,
#    'ext_damaged': 295},
#   'places_of_worship': {'mosques_destroyed': 161,
#    'ext_mosques_destroyed': 161,
#    'mosques_damaged': 253,
#    'ext_mosques_damaged': 253,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 70000, 'ext_destroyed': 70000}},
#  {'report_date': '2024-01-31',
#   'civic_buildings': {'ext_destroyed': 140},
#   'educational_buildings': {'ext_destroyed': 99, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 167,
#    'ext_mosques_damaged': 256,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-02-01',
#   'civic_buildings': {'ext_destroyed': 140},
#   'educational_buildings': {'ext_destroyed': 100, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 172,
#    'ext_mosques_damaged': 259,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-02-02',
#   'civic_buildings': {'ext_destroyed': 140},
#   'educational_buildings': {'ext_destroyed': 100, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 178,
#    'ext_mosques_damaged': 261,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-02-03',
#   'civic_buildings': {'destroyed': 140, 'ext_destroyed': 140},
#   'educational_buildings': {'destroyed': 100,
#    'ext_destroyed': 100,
#    'damaged': 295,
#    'ext_damaged': 295},
#   'places_of_worship': {'mosques_destroyed': 183,
#    'ext_mosques_destroyed': 183,
#    'mosques_damaged': 264,
#    'ext_mosques_damaged': 264,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 70000, 'ext_destroyed': 70000}},
#  {'report_date': '2024-02-04',
#   'civic_buildings': {'ext_destroyed': 140},
#   'educational_buildings': {'ext_destroyed': 100, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 183,
#    'ext_mosques_damaged': 264,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-02-05',
#   'civic_buildings': {'ext_destroyed': 141},
#   'educational_buildings': {'ext_destroyed': 100, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 183,
#    'ext_mosques_damaged': 265,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-02-06',
#   'civic_buildings': {'ext_destroyed': 141},
#   'educational_buildings': {'ext_destroyed': 100, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 183,
#    'ext_mosques_damaged': 265,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-02-07',
#   'civic_buildings': {'ext_destroyed': 141},
#   'educational_buildings': {'ext_destroyed': 100, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 184,
#    'ext_mosques_damaged': 265,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-02-08',
#   'civic_buildings': {'ext_destroyed': 141},
#   'educational_buildings': {'destroyed': 100,
#    'ext_destroyed': 100,
#    'damaged': 295,
#    'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 184,
#    'ext_mosques_damaged': 265,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-02-09',
#   'civic_buildings': {'ext_destroyed': 142},
#   'educational_buildings': {'ext_destroyed': 100, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 184,
#    'ext_mosques_damaged': 266,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-02-10',
#   'civic_buildings': {'ext_destroyed': 142},
#   'educational_buildings': {'ext_destroyed': 100, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 184,
#    'ext_mosques_damaged': 266,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-02-11',
#   'civic_buildings': {'destroyed': 142, 'ext_destroyed': 142},
#   'educational_buildings': {'destroyed': 100,
#    'ext_destroyed': 100,
#    'damaged': 295,
#    'ext_damaged': 295},
#   'places_of_worship': {'mosques_destroyed': 184,
#    'ext_mosques_destroyed': 184,
#    'mosques_damaged': 266,
#    'ext_mosques_damaged': 266,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 70000, 'ext_destroyed': 70000}},
#  {'report_date': '2024-02-12',
#   'civic_buildings': {'ext_destroyed': 142},
#   'educational_buildings': {'ext_destroyed': 100, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 184,
#    'ext_mosques_damaged': 266,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-02-13',
#   'civic_buildings': {'ext_destroyed': 142},
#   'educational_buildings': {'ext_destroyed': 100, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 184,
#    'ext_mosques_damaged': 266,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-02-14',
#   'civic_buildings': {'ext_destroyed': 142},
#   'educational_buildings': {'ext_destroyed': 100, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 184,
#    'ext_mosques_damaged': 266,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-02-15',
#   'civic_buildings': {'ext_destroyed': 142},
#   'educational_buildings': {'ext_destroyed': 100, 'ext_damaged': 295},
#   'places_of_worship': {'ext_mosques_destroyed': 184,
#    'ext_mosques_damaged': 266,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-02-16',
#   'civic_buildings': {'destroyed': 142, 'ext_destroyed': 142},
#   'educational_buildings': {'destroyed': 100,
#    'ext_destroyed': 100,
#    'damaged': 295,
#    'ext_damaged': 295},
#   'places_of_worship': {'mosques_destroyed': 184,
#    'ext_mosques_destroyed': 184,
#    'mosques_damaged': 266,
#    'ext_mosques_damaged': 266,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 70000, 'ext_destroyed': 70000}},
#  {'report_date': '2024-02-17',
#   'civic_buildings': {'destroyed': 142, 'ext_destroyed': 142},
#   'educational_buildings': {'destroyed': 100,
#    'ext_destroyed': 100,
#    'damaged': 295,
#    'ext_damaged': 295},
#   'places_of_worship': {'mosques_destroyed': 184,
#    'ext_mosques_destroyed': 184,
#    'mosques_damaged': 266,
#    'ext_mosques_damaged': 266,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 70000, 'ext_destroyed': 70000}},
#  {'report_date': '2024-02-18',
#   'civic_buildings': {'ext_destroyed': 144},
#   'educational_buildings': {'ext_destroyed': 100, 'ext_damaged': 297},
#   'places_of_worship': {'ext_mosques_destroyed': 188,
#    'ext_mosques_damaged': 268,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-02-19',
#   'civic_buildings': {'ext_destroyed': 146},
#   'educational_buildings': {'ext_destroyed': 100, 'ext_damaged': 298},
#   'places_of_worship': {'ext_mosques_destroyed': 192,
#    'ext_mosques_damaged': 270,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-02-20',
#   'civic_buildings': {'ext_destroyed': 148},
#   'educational_buildings': {'ext_destroyed': 100, 'ext_damaged': 300},
#   'places_of_worship': {'ext_mosques_destroyed': 196,
#    'ext_mosques_damaged': 272,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-02-21',
#   'civic_buildings': {'ext_destroyed': 151},
#   'educational_buildings': {'ext_destroyed': 100, 'ext_damaged': 301},
#   'places_of_worship': {'ext_mosques_destroyed': 200,
#    'ext_mosques_damaged': 274,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 70000}},
#  {'report_date': '2024-02-22',
#   'civic_buildings': {'ext_destroyed': 153},
#   'educational_buildings': {'ext_destroyed': 100, 'ext_damaged': 303},
#   'places_of_worship': {'ext_mosques_destroyed': 204,
# ...
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-01-27',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-01-28',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-01-29',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-01-30',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-01-31',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-01',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-02',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-03',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-04',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-05',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-06',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-07',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-08',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-09',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-10',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-11',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-12',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-13',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-14',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-15',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-16',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-17',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-18',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-19',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-20',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-21',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-22',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-23',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-24',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-25',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-26',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-27',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-02-28',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-03-01',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-03-02',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-03-03',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-03-04',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-03-05',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-03-06',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-03-07',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-03-08',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-03-09',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-03-10',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-03-11',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-03-12',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-03-13',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-03-14',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-03-15',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-03-16',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-03-17',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-03-18',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-03-19',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-03-20',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-03-21',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-03-22',
#   'civic_buildings': {'ext_destroyed': 216},
#   'educational_buildings': {'ext_destroyed': 137, 'ext_damaged': 357},
#   'places_of_worship': {'ext_mosques_destroyed': 823,
#    'ext_churches_destroyed': 3},
#   'residential': {'ext_destroyed': 161600}},
#  {'report_date': '2025-03-23',
#   'civic_buildings': {'destroyed': 221, 'ext_destroyed': 221},
#   'educational_buildings': {'destroyed': 139,
#    'ext_destroyed': 139,
#    'damaged': 359,
#    'ext_damaged': 359},
#   'places_of_worship': {'mosques_destroyed': 825,
#    'ext_mosques_destroyed': 825,
#    'churches_destroyed': 3,
#    'ext_churches_destroyed': 3},
#   'residential': {'destroyed': 165000, 'ext_destroyed': 165000}}]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Casualties Daily Cleaning

# %%
# 1. Check initial structure
casualties.info()
casualties.head()

# 2. Convert report_date to datetime
casualties['report_date'] = pd.to_datetime(casualties['report_date'], errors='coerce')

# 3. Handle missing values
# Fill missing 'killed', 'killed_cum', 'injured_cum' carefully
casualties['killed'] = casualties['killed'].fillna(0)
casualties['killed_cum'] = casualties['killed_cum'].ffill()  # Forward fill cumulative counts
casualties['injured_cum'] = casualties['injured_cum'].ffill()

# Optional for 'med_killed_cum' and 'press_killed_cum' if they exist
for col in ['med_killed_cum', 'press_killed_cum']:
    if col in casualties.columns:
        casualties[col] = casualties[col].fillna(0)

# 4. Standardise data types
casualties['killed'] = casualties['killed'].astype(int)
casualties['killed_cum'] = casualties['killed_cum'].astype(int)
casualties['injured_cum'] = casualties['injured_cum'].astype(int)

# 5. (Optional) Drop redundant internal counts
# casualties = casualties.drop(columns=['killed_internal', 'injured_internal'], errors='ignore')

# 6. Save cleaned file
casualties.to_csv('/kaggle/working/cleaned_casualties_daily.csv', index=False)

print("Casualties Daily Cleaning Completed and Saved!")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 554 entries, 0 to 553
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   report_date              554 non-null    datetime64[ns]
#  1   report_source            554 non-null    object
#  2   report_period            554 non-null    int64
#  3   ext_massacres_cum        554 non-null    int64
#  4   killed                   554 non-null    int64
#  5   killed_cum               554 non-null    int64
#  6   ext_killed               554 non-null    int64
#  7   ext_killed_cum           554 non-null    int64
#  8   ext_killed_children_cum  554 non-null    int64
#  9   ext_killed_women_cum     554 non-null    int64
#  10  injured_cum              554 non-null    int64
#  11  ext_injured              554 non-null    int64
#  12  ext_injured_cum          554 non-null    int64
#  13  ext_civdef_killed_cum    554 non-null    int64
#  14  med_killed_cum           554 non-null    float64
#  15  ext_med_killed_cum       554 non-null    int64
#  16  press_killed_cum         554 non-null    float64
#  17  ext_press_killed_cum     554 non-null    int64
# dtypes: datetime64[ns](1), float64(2), int64(14), object(1)
# memory usage: 78.0+ KB
# Casualties Daily Cleaning Completed and Saved!

# %%
casualties.info()
casualties.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 554 entries, 0 to 553
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   report_date              554 non-null    datetime64[ns]
#  1   report_source            554 non-null    object
#  2   report_period            554 non-null    int64
#  3   ext_massacres_cum        554 non-null    int64
#  4   killed                   554 non-null    int64
#  5   killed_cum               554 non-null    int64
#  6   ext_killed               554 non-null    int64
#  7   ext_killed_cum           554 non-null    int64
#  8   ext_killed_children_cum  554 non-null    int64
#  9   ext_killed_women_cum     554 non-null    int64
#  10  injured_cum              554 non-null    int64
#  11  ext_injured              554 non-null    int64
#  12  ext_injured_cum          554 non-null    int64
#  13  ext_civdef_killed_cum    554 non-null    int64
#  14  med_killed_cum           554 non-null    float64
#  15  ext_med_killed_cum       554 non-null    int64
#  16  press_killed_cum         554 non-null    float64
#  17  ext_press_killed_cum     554 non-null    int64
# dtypes: datetime64[ns](1), float64(2), int64(14), object(1)
# memory usage: 78.0+ KB
#   report_date report_source  report_period  ext_massacres_cum  killed  \
# 0  2023-10-07        mohtel             24                  0     232
# 1  2023-10-08        mohtel             24                  0     138
# 2  2023-10-09        mohtel             24                  8     190
# 3  2023-10-10        mohtel             24                  8     340
# 4  2023-10-11        gmotel             24                 23     200
#
#    killed_cum  ext_killed  ext_killed_cum  ext_killed_children_cum  \
# 0         232         232             232                        0
# 1         370         138             370                       78
# 2         560         190             560                       91
# 3         900         340             900                      260
# 4        1100         200            1100                      398
#
#    ext_killed_women_cum  injured_cum  ext_injured  ext_injured_cum  \
# 0                     0         1610         1610             1610
# 1                    41         1788          178             1788
# 2                    61         2271          483             2271
# 3                   230         4000         1729             4000
# 4                   230         5184         1184             5184
#
#    ext_civdef_killed_cum  med_killed_cum  ext_med_killed_cum  \
# 0                      0             6.0                   6
# 1                      0             0.0                   6
# 2                      0             6.0                   6
# 3                      0             0.0                   6
# 4                      0            10.0                  10
#
#    press_killed_cum  ext_press_killed_cum
# 0               1.0                     1
# 1               1.0                     1
# 2               3.0                     3
# 3               7.0                     7
# 4               0.0                     7

# %% [markdown]
# ### West Bank Daily Cleaning

# %%
# 1. Check initial structure
west_bank.info()
west_bank.head()

# 2. Convert report_date to datetime
west_bank['report_date'] = pd.to_datetime(west_bank['report_date'], errors='coerce')

# 3. Handle missing values
# Find all columns starting with 'verified'
verified_cols = [col for col in west_bank.columns if col.startswith('verified')]

# Fill missing values in verified columns with 0
west_bank[verified_cols] = west_bank[verified_cols].fillna(0)

# 4. Standardise data types
west_bank[verified_cols] = west_bank[verified_cols].astype(int)

# 5. (Optional) Focus only on verified data
# If you want to drop internal counts (non-verified fields), you can uncomment this:
# non_verified_cols = [col for col in west_bank.columns if col.startswith('internal')]
# west_bank = west_bank.drop(columns=non_verified_cols, errors='ignore')

# 6. Save cleaned file
west_bank.to_csv('/kaggle/working/cleaned_west_bank_daily.csv', index=False)

print("West Bank Daily Cleaning Completed and Saved!")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 554 entries, 0 to 553
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   report_date                    554 non-null    object
#  1   verified.killed                403 non-null    float64
#  2   verified.killed_cum            404 non-null    float64
#  3   verified.injured               389 non-null    float64
#  4   verified.injured_cum           391 non-null    float64
#  5   verified.killed_children       403 non-null    float64
#  6   verified.killed_children_cum   404 non-null    float64
#  7   verified.injured_children      389 non-null    float64
#  8   verified.injured_children_cum  391 non-null    float64
#  9   killed_cum                     554 non-null    int64
#  10  killed_children_cum            554 non-null    int64
#  11  injured_cum                    554 non-null    int64
#  12  injured_children_cum           554 non-null    int64
#  13  settler_attacks_cum            554 non-null    int64
#  14  flash_source                   554 non-null    object
# dtypes: float64(8), int64(5), object(2)
# memory usage: 65.1+ KB
# West Bank Daily Cleaning Completed and Saved!

# %%
# Quick Verification

# 1. Check for any remaining missing values
missing_values = west_bank.isnull().sum()
print("Missing Values:\n", missing_values)

# 2. Check data types
print("\nData Types:\n", west_bank.dtypes)

# 3. Preview a few rows
west_bank.head()

# 4. Quick Date Range Check
print("\nDate Range:")
print(f"From {west_bank['report_date'].min()} to {west_bank['report_date'].max()}")
# Out:
# Missing Values:
#  report_date                      0
# verified.killed                  0
# verified.killed_cum              0
# verified.injured                 0
# verified.injured_cum             0
# verified.killed_children         0
# verified.killed_children_cum     0
# verified.injured_children        0
# verified.injured_children_cum    0
# killed_cum                       0
# killed_children_cum              0
# injured_cum                      0
# injured_children_cum             0
# settler_attacks_cum              0
# flash_source                     0
# dtype: int64
#
# Data Types:
#  report_date                      datetime64[ns]
# verified.killed                           int64
# verified.killed_cum                       int64
# verified.injured                          int64
# verified.injured_cum                      int64
# verified.killed_children                  int64
# verified.killed_children_cum              int64
# verified.injured_children                 int64
# verified.injured_children_cum             int64
# killed_cum                                int64
# killed_children_cum                       int64
# injured_cum                               int64
# injured_children_cum                      int64
# settler_attacks_cum                       int64
# flash_source                             object
# dtype: object
#
# Date Range:
# From 2023-10-07 00:00:00 to 2025-04-12 00:00:00

# %% [markdown]
# ### Press Killed Cleaning

# %%
# 1. Check initial structure
press_killed.info()
press_killed.head()

# 2. Handle missing values
# Fill missing 'notes' field with a standard placeholder
if 'notes' in press_killed.columns:
    press_killed['notes'] = press_killed['notes'].fillna('Details not available')

# 3. (Optional) Future analysis prep: Extract structured fields
# For now, we'll just clean — deeper extraction can be a bonus project

# 4. Save cleaned file
press_killed.to_csv('/kaggle/working/cleaned_press_killed_in_gaza.csv', index=False)

print("Press Killed Cleaning Completed and Saved!")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     209 non-null    object
#  1   name_en  209 non-null    object
#  2   notes    156 non-null    object
# dtypes: object(3)
# memory usage: 5.0+ KB
# Press Killed Cleaning Completed and Saved!

# %%
# Quick Verification

# 1. Check for missing values
missing_values_press = press_killed.isnull().sum()
print("Missing Values:\n", missing_values_press)

# 2. Check data types
print("\nData Types:\n", press_killed.dtypes)

# 3. Preview a few rows
press_killed.head()

# 4. Quick Date Range Check (optional)
if 'date_of_death' in press_killed.columns:
    press_killed['date_of_death'] = pd.to_datetime(press_killed['date_of_death'], errors='coerce')
    print("\nDate Range:")
    print(f"From {press_killed['date_of_death'].min()} to {press_killed['date_of_death'].max()}")
# Out:
# Missing Values:
#  name       0
# name_en    0
# notes      0
# dtype: int64
#
# Data Types:
#  name       object
# name_en    object
# notes      object
# dtype: object

# %% [markdown]
# ### Infrastructure Damaged Cleaning

# %%
# 1. Flatten the JSON structure
infra_flat = pd.json_normalize(infra_json)

# 2. Standardise column names: lowercase + underscores
infra_flat.columns = infra_flat.columns.str.lower().str.replace(' ', '_').str.replace('.', '_')

# 3. Convert report_date to datetime
if 'report_date' in infra_flat.columns:
    infra_flat['report_date'] = pd.to_datetime(infra_flat['report_date'], errors='coerce')

# 4. (Optional) Quickly check structure
infra_flat.info()
infra_flat.head()

# 5. Save cleaned file
infra_flat.to_csv('/kaggle/working/cleaned_infrastructure_damaged.csv', index=False)

print("Infrastructure Damaged Cleaning Completed and Saved!")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 534 entries, 0 to 533
# Data columns (total 15 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   report_date                               534 non-null    datetime64[ns]
#  1   civic_buildings_ext_destroyed             534 non-null    int64
#  2   educational_buildings_ext_destroyed       534 non-null    int64
#  3   educational_buildings_ext_damaged         534 non-null    int64
#  4   places_of_worship_ext_mosques_destroyed   534 non-null    int64
#  5   places_of_worship_ext_mosques_damaged     360 non-null    float64
#  6   places_of_worship_ext_churches_destroyed  534 non-null    int64
#  7   residential_ext_destroyed                 534 non-null    int64
#  8   residential_destroyed                     106 non-null    float64
#  9   civic_buildings_destroyed                 83 non-null     float64
#  10  educational_buildings_destroyed           89 non-null     float64
#  11  educational_buildings_damaged             90 non-null     float64
#  12  places_of_worship_mosques_destroyed       81 non-null     float64
#  13  places_of_worship_mosques_damaged         70 non-null     float64
#  14  places_of_worship_churches_destroyed      83 non-null     float64
# dtypes: datetime64[ns](1), float64(8), int64(6)
# memory usage: 62.7 KB
# Infrastructure Damaged Cleaning Completed and Saved!

# %%
# Quick Verification

# 1. Check for missing values
missing_values_infra = infra_flat.isnull().sum()
print("Missing Values:\n", missing_values_infra)

# 2. Check data types
print("\nData Types:\n", infra_flat.dtypes)

# 3. Preview a few rows
infra_flat.head()

# 4. Quick Date Range Check
if 'report_date' in infra_flat.columns:
    print("\nDate Range:")
    print(f"From {infra_flat['report_date'].min()} to {infra_flat['report_date'].max()}")
# Out:
# Missing Values:
#  report_date                                   0
# civic_buildings_ext_destroyed                 0
# educational_buildings_ext_destroyed           0
# educational_buildings_ext_damaged             0
# places_of_worship_ext_mosques_destroyed       0
# places_of_worship_ext_mosques_damaged       174
# places_of_worship_ext_churches_destroyed      0
# residential_ext_destroyed                     0
# residential_destroyed                       428
# civic_buildings_destroyed                   451
# educational_buildings_destroyed             445
# educational_buildings_damaged               444
# places_of_worship_mosques_destroyed         453
# places_of_worship_mosques_damaged           464
# places_of_worship_churches_destroyed        451
# dtype: int64
#
# Data Types:
#  report_date                                 datetime64[ns]
# civic_buildings_ext_destroyed                        int64
# educational_buildings_ext_destroyed                  int64
# educational_buildings_ext_damaged                    int64
# places_of_worship_ext_mosques_destroyed              int64
# places_of_worship_ext_mosques_damaged              float64
# places_of_worship_ext_churches_destroyed             int64
# residential_ext_destroyed                            int64
# residential_destroyed                              float64
# civic_buildings_destroyed                          float64
# educational_buildings_destroyed                    float64
# educational_buildings_damaged                      float64
# places_of_worship_mosques_destroyed                float64
# places_of_worship_mosques_damaged                  float64
# places_of_worship_churches_destroyed               float64
# dtype: object
#
# Date Range:
# From 2023-10-07 00:00:00 to 2025-03-23 00:00:00

# %% [markdown]
# *End of data cleaning process
